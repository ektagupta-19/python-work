# %%
#Create a dataframe from the file ‘marks.csv’ and print the contents of the dataframe. Open the file from the link above and inspect the required elements in the file (header, separator, etc.). If the top row is a regular entry, do not load it as the column header.
import numpy as np
import pandas as pd

df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv', sep='|', header=None)
print(df)
# Out:
#      0        1            2   3   4   5
# 0    1   Akshay  Mathematics  50  40  80
# 1    2   Mahima      English  40  33  83
# 2    3    Vikas  Mathematics  50  42  84
# 3    4  Abhinav      English  40  31  78
# 4    5   Mahima      Science  50  40  80
# 5    6   Akshay      Science  50  49  98
# 6    7  Abhinav  Mathematics  50  47  94
# 7    8    Vikas      Science  50  40  80
# 8    9  Abhinav      Science  50  47  94
# 9   10    Vikas      English  40  39  98
# 10  11   Akshay      English  40  35  88
# 11  12   Mahima  Mathematics  50  43  86

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/A08MajL8qN4rq72EpVJbAP1Rw/marks_1.csv', sep='|', header=None, index_col=0)

df.index.name='S.No.'
df.columns=['Name', 'Subject', 'Maximum Marks', 'Marks Obtained', 'Percentage']
print(df)

# %%
# Create a hierarchical index based on two columns: Office and Department,Print the first 5 rows as the output
import numpy as np
import pandas as pd
 
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv', index_col=(2,1))
#df.set_index(['Office', 'Department'])
df.sort_index(inplace=True) 
print(df.head(5))
# Out:
#                          ID  Rating
# Office    Department
# Bangalore Finance     U2F53     2.7
#           Finance     U1F53     3.7
#           Finance     U1F28     3.2
#           Finance     U1F15     3.3
#           Finance     U1F14     2.9

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
print(df.describe())
print(df.columns)
print(df.shape)

# %%
#print columns
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2 = df[['month', 'day', 'temp', 'area']]
print(df_2.head(20))

# %%
# Print only the even numbers of rows of the dataframe 'df'.
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2 = df.iloc[2:-1:2,:]
print(df_2.head(20))

# %%
#Print all the columns and the rows where 'area' is greater than 0, 'wind' is greater than 1 and the 'temp' is greater than 15.
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')
df_2 =  df[(df["area"]>0) & (df["wind"]>1) & (df["temp"]>15)]
print(df_2.head(20))
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain  area
# 138  9  9   jul  tue  85.8   48.3  313.4   3.9  18.0  42   2.7   0.0  0.36
# 139  1  4   sep  tue  91.0  129.5  692.6   7.0  21.7  38   2.2   0.0  0.43
# 140  2  5   sep  mon  90.9  126.5  686.5   7.0  21.9  39   1.8   0.0  0.47
# 141  1  2   aug  wed  95.5   99.9  513.3  13.2  23.3  31   4.5   0.0  0.55
# 142  8  6   aug  fri  90.1  108.0  529.8  12.5  21.2  51   8.9   0.0  0.61
# 143  1  2   jul  sat  90.0   51.3  296.3   8.7  16.6  53   5.4   0.0  0.71
# 144  2  5   aug  wed  95.5   99.9  513.3  13.2  23.8  32   5.4   0.0  0.77
# 145  6  5   aug  thu  95.2  131.7  578.8  10.4  27.4  22   4.0   0.0  0.90
# 147  8  3   sep  tue  84.4   73.4  671.9   3.2  24.2  28   3.6   0.0  0.96
# 148  2  2   aug  tue  94.8  108.3  647.1  17.0  17.4  43   6.7   0.0  1.07
# 149  8  6   sep  thu  93.7   80.9  685.2  17.9  23.7  25   4.5   0.0  1.12
# 150  6  5   jun  fri  92.5   56.4  433.3   7.1  23.2  39   5.4   0.0  1.19
# 151  9  9   jul  sun  90.1   68.6  355.2   7.2  24.8  29   2.2   0.0  1.36
# 152  3  4   jul  sat  90.1   51.2  424.1   6.2  24.6  43   1.8   0.0  1.43
# 153  5  4   sep  fri  94.3   85.1  692.3  15.9  20.1  47   4.9   0.0  1.46
# 154  1  5   sep  sat  93.4  145.4  721.4   8.1  29.6  27   2.7   0.0  1.46
# 155  7  4   aug  sun  94.8  108.3  647.1  17.0  16.4  47   1.3   0.0  1.56
# 156  2  4   sep  sat  93.4  145.4  721.4   8.1  28.6  27   2.2   0.0  1.61
# 157  2  2   aug  wed  92.1  111.2  654.1   9.6  18.4  45   3.6   0.0  1.63
# 158  2  4   aug  wed  92.1  111.2  654.1   9.6  20.5  35   4.0   0.0  1.64

# %%
# You are provided with the dataset of a company which has offices across three cities - Mumbai, Bangalore and New Delhi. The dataset contains the rating (out of 5) of all the employees from different departments (Finance, HR, Marketing and Sales). 
#The company has come up with a new policy that any individual with a rating equal to or below 3.5 needs to attend a training. Using dataframes, load the dataset and then derive the column ‘Training’ which shows ‘Yes’ for people who require training and ‘No’ for those who do not.
#Print the first 5 rows as the output
import numpy as np
import pandas as pd
 
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
df["Training"]= df.Rating.apply(lambda x: "Yes" if x<=3.5 else "No") 
print(df.head(5))
# Out:
#       ID Department     Office  Rating Training
# 0  U2F26    Finance  New Delhi     3.4      Yes
# 1  U2M61  Marketing  New Delhi     3.9       No
# 2  U1S15      Sales  New Delhi     2.8      Yes
# 3  U1H87         HR     Mumbai     2.1      Yes
# 4  U1S51      Sales  New Delhi     4.6       No

# %%
import numpy as np
import pandas as pd
 
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/NMgEjwkAEGGQZBoNYGr9Ld7w0/rating.csv')
df["Training"]= df.Rating.apply(lambda x: "Yes" if x<=3.5 else "No") 
#print(df[df["Training"]=="Yes"])

for i in ['Finance', 'HR', 'Sales', 'Marketing']:
    print(i, len(df[(df['Training'] == 'No') & (df['Department'] == i)]) / len(df[df['Department'] == i]) * 100)
# Out:
# Finance 50.0
# HR 57.25190839694656
# Sales 49.23076923076923
# Marketing 46.3768115942029

# %%
#Group the dataframe 'df' by 'month' and 'day' and find the mean value for column 'rain' and 'wind'.
import pandas as pd
df = pd.read_csv('https://cdn.upgrad.com/uploads/production/b3467ba4-4e13-44e9-8087-4d7e94cc7586/forestfires.csv')

df_1 = df.groupby(by=["month", "day"])['rain', 'wind'].mean()
print(df_1.head(20))

# %%
#Perform an inner merge on two data frames df_1 and df_2 on  'unique_id' and print the combined dataframe.
import pandas as pd
df_1 = pd.read_csv('https://cdn.upgrad.com/uploads/production/1ed2840b-f083-44fe-9eb4-acda009ac620/restaurant-1.csv')
df_2 = pd.read_csv('https://cdn.upgrad.com/uploads/production/c87b99b4-467c-4128-8729-85bff0b0acbe/restaurant-2.csv')
df_3 = df_1.merge(df_2,on="unique_id", how="inner")
print(df_3.head(20))

# %%
#Append two datasets df_1 and df_2, and print the combined dataframe.
import warnings
warnings.simplefilter("ignore")

import pandas as pd
df_1 = pd.read_csv('https://cdn.upgrad.com/uploads/production/1ed2840b-f083-44fe-9eb4-acda009ac620/restaurant-1.csv')
df_2 = pd.read_csv('https://cdn.upgrad.com/uploads/production/c87b99b4-467c-4128-8729-85bff0b0acbe/restaurant-2.csv')
df_3 =pd.concat([df_1,df_2], axis=0)

print(df_3.head())

# %%
import pandas as pd
# Import and read the movie database. Store it in a variable called `movies`.
movies=pd.read_csv("Movies.csv")

# Inspect the dataframe's columns, shapes, variable types etc.
movies.shape
movies.dtypes

# Question 1: How many rows and columns are present in the dataframe?
movies.shape

# Question 2: How many columns have null values present in them? 
# Try writing a code for this instead of counting them manually.

len(movies.columns[movies.isna().any()].tolist())

# Drop these column and find new data set
#For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
#-  color
#-  director_facebook_likes
#-  actor_1_facebook_likes
#-  actor_2_facebook_likes
#-  actor_3_facebook_likes
#-  actor_2_name
#-  cast_total_facebook_likes
#-  actor_3_name
#-  duration
#-  facenumber_in_poster
#-  content_rating
#-  country
#-  movie_imdb_link
#-  aspect_ratio
#-  plot_keywords

# Question 3: What is the count of columns in the new dataframe?

movies=movies.drop(['color','director_facebook_likes', 'actor_1_facebook_likes', 'actor_2_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'cast_total_facebook_likes', 'actor_3_name', 'duration', 'facenumber_in_poster', 'content_rating', 'country', 'movie_imdb_link', 'aspect_ratio', 'plot_keywords'], axis=1)
movies.shape
# Out:
# (3853, 13)

# %%
# there are null values in multiple columns of the dataframe 'movies'. Find out the percentage of null values in each column of the dataframe 'movies'. 
# Question 4: Which column has the highest percentage of null values
round(100*(movies.isnull().sum()/len(movies.index)), 2)
# one more way
mov=movies.iloc[:, :].isnull().sum()/movies.count()
mov.sort_values(ascending=False)
# Out:
# RangeIndex(start=0, stop=3853, step=1)

# %%
# the `language` column has some NaN values. Here, on inspection, 
# you will see that it is safe to replace all the missing values with `'English'`

# Question 5: What is the count of movies made in English language after replacing the NaN values with English? 
#movies.fillna('English', inplace=True)
#movies=movies[movies['language']=='English']
#movies.count()

movies.loc[pd.isnull(movies['language']), ['language']] = 'English'
(movies.language == 'English').sum()
# Out:
# 3674

# %%
# Find the movies with highest profit**

   #1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
   #2. Sort the dataframe using the `profit` column as reference. (Find 
   # which command can be used here to sort entries from the documentation)
   #3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

movies['profit']= movies['gross']- movies['budget']
movies.sort_values('profit', inplace=True, ascending=False)
top10= movies.head(10)


# Question 6: Which movie is ranked 5th from the top in the list obtained? 
top10.iloc[4]
# Out:
# director_name                        Steven Spielberg
# num_critic_for_reviews                          215.0
# gross                                     434949459.0
# genres                                  Family|Sci-Fi
# actor_1_name                             Henry Thomas
# movie_title               E.T. the Extra-Terrestrial
# num_voted_users                                281842
# num_user_for_reviews                            515.0
# language                                      English
# budget                                     10500000.0
# title_year                                     1982.0
# imdb_score                                        7.9
# movie_facebook_likes                            34000
# Language                                      English
# profit                                    424449459.0
# Name: 2748, dtype: object

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250''
 
IMDb_Top_250= movies.sort_values('imdb_score', ascending=False)
 
IMDb_Top_250[IMDb_Top_250['num_voted_users']>25000]
IMDb_Top_250=IMDb_Top_250.head(250)
IMDb_Top_250['Rank']=IMDb_Top_250['imdb_score'].rank()
IMDb_Top_250
# Out:
#              director_name num_critic_for_reviews        gross  \
# 1795        Frank Darabont                  199.0   28341469.0
# 3016  Francis Ford Coppola                  208.0  134821952.0
# 2543  Francis Ford Coppola                  149.0   57300000.0
# 64       Christopher Nolan                  645.0  533316061.0
# 2938     Quentin Tarantino                  215.0  107930000.0
# ...                    ...                    ...          ...
# 2663        Richard Curtis                  274.0   15294553.0
# 3450           James Ivory                   29.0    3130592.0
# 1068          Andrew Davis                  119.0  183875760.0
# 1682         Paul McGuigan                  202.0   22494487.0
# 1649            Joe Wright                  177.0   38372662.0
#
#                                              genres    actor_1_name  \
# 1795                                    Crime|Drama  Morgan Freeman
# 3016                                    Crime|Drama       Al Pacino
# 2543                                    Crime|Drama  Robert De Niro
# 64                      Action|Crime|Drama|Thriller  Christian Bale
# 2938                                    Crime|Drama    Bruce Willis
# ...                                             ...             ...
# 2663                          Drama|Fantasy|Romance      Tom Hughes
# 3450                                  Drama|Romance   Rupert Graves
# 1068  Action|Adventure|Crime|Drama|Mystery|Thriller   Harrison Ford
# 1682                   Crime|Drama|Mystery|Thriller    Bruce Willis
# 1649                                  Drama|Romance   Talulah Riley
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 1795  The Shawshank Redemption           1689764                4144.0
# 3016             The Godfather           1155770                2238.0
# 2543    The Godfather: Part II            790926                 650.0
# 64             The Dark Knight           1676169                4667.0
# 2938              Pulp Fiction           1324680                2195.0
# ...                         ...              ...                   ...
# 2663                About Time            202341                 391.0
# 3450                   Maurice             10755                  69.0
# 1068              The Fugitive            213668                 270.0
# 1682       Lucky Number Slevin            262153                 507.0
# 1649         Pride & Prejudice            193455                1058.0
#
#      language       budget  title_year  imdb_score  movie_facebook_likes  \
# 1795  English   25000000.0      1994.0         9.3                108000
# 3016  English    6000000.0      1972.0         9.2                 43000
# 2543  English   13000000.0      1974.0         9.0                 14000
# 64    English  185000000.0      2008.0         9.0                 37000
# 2938  English    8000000.0      1994.0         8.9                 45000
# ...       ...          ...         ...         ...                   ...
# 2663  English   12000000.0      2013.0         7.8                105000
# 3450  English    2600000.0      1987.0         7.8                   963
# 1068  English   44000000.0      1993.0         7.8                     0
# 1682  English   27000000.0      2006.0         7.8                 10000
# 1649  English   28000000.0      2005.0         7.8                 17000
#
#      Language       profit   Rank
# 1795  English    3341469.0  250.0
# 3016  English  128821952.0  249.0
# 2543  English   44300000.0  247.5
# 64    English  348316061.0  247.5
# 2938  English   99930000.0  245.0
# ...       ...          ...    ...
# 2663  English    3294553.0   12.5
# 3450  English     530592.0   12.5
# 1068  English  139875760.0   12.5
# 1682  English   -4505513.0   12.5
# 1649  English   10372662.0   12.5
#
# [250 rows x 16 columns]

# %%
#Question 7: Suppose movies are divided into 5 buckets based on the IMDb ratings: 
#Which bucket holds the maximum number of movies from *IMDb_Top_250*? 

IMDb_Top_250_1=IMDb_Top_250[IMDb_Top_250['imdb_score']<= 8]
 
len(IMDb_Top_250_1[IMDb_Top_250_1['imdb_score']>= 7.5 ])
# Out:
# 117

# %%
IMDb_Top_250_2=IMDb_Top_250[IMDb_Top_250['imdb_score']<= 8.5]
 
len(IMDb_Top_250_2[IMDb_Top_250_2['imdb_score']>= 8 ])
# Out:
# 159

# %%
IMDb_Top_250_3=IMDb_Top_250[IMDb_Top_250['imdb_score']<= 9]
len(IMDb_Top_250_3[IMDb_Top_250_3['imdb_score']>= 8.5 ])
# Out:
# 38

# %%
IMDb_Top_250_4=IMDb_Top_250[IMDb_Top_250['imdb_score']<=9.5 ]
len(IMDb_Top_250_4[IMDb_Top_250_4['imdb_score']>= 9 ])
# Out:
# 4

# %%
IMDb_Top_250_5=IMDb_Top_250[IMDb_Top_250['imdb_score']<= 10]
len(IMDb_Top_250_5[IMDb_Top_250_5['imdb_score']>= 9.5 ])
# Out:
# 0

# %%
IMDb_Top_250 = movies.sort_values(by = 'imdb_score', ascending = False)
IMDb_Top_250 = IMDb_Top_250.loc[IMDb_Top_250.num_voted_users > 25000]
IMDb_Top_250 = IMDb_Top_250.iloc[:250, ]
IMDb_Top_250['Rank'] = range(1,251)

import matplotlib.pyplot as plt
plt.hist(IMDb_Top_250['imdb_score'], bins = 5, range = (7.5,10), edgecolor = 'cyan')
plt.show()

# %%
# Write your code for creating three new dataframes here
# Include all movies in which Meryl_Streep is the lead

Meryl_Streep = movies[movies['actor_1_name']=='Meryl Streep']
# Out:
#        director_name num_critic_for_reviews        gross  \
# 1784  Stephen Daldry                  174.0   41597830.0
# 1471  Sydney Pollack                   66.0   87100000.0
# 1563   Carl Franklin                   64.0   23209440.0
# 1132     Nora Ephron                  252.0   94125426.0
# 2793   Robert Altman                  211.0   20338609.0
# 1322   David Frankel                  208.0  124732962.0
# 392     Nancy Meyers                  187.0  112703470.0
# 2500  Phyllida Lloyd                  331.0   29959436.0
# 1514   David Frankel                  234.0   63536011.0
# 1038   Curtis Hanson                   42.0   46815748.0
# 1390  Robert Redford                  227.0   14998070.0
#
#                                genres  actor_1_name  \
# 1784                    Drama|Romance  Meryl Streep
# 1471          Biography|Drama|Romance  Meryl Streep
# 1563                            Drama  Meryl Streep
# 1132          Biography|Drama|Romance  Meryl Streep
# 2793               Comedy|Drama|Music  Meryl Streep
# 1322             Comedy|Drama|Romance  Meryl Streep
# 392              Comedy|Drama|Romance  Meryl Streep
# 2500          Biography|Drama|History  Meryl Streep
# 1514             Comedy|Drama|Romance  Meryl Streep
# 1038  Action|Adventure|Crime|Thriller  Meryl Streep
# 1390               Drama|Thriller|War  Meryl Streep
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 1784                 The Hours            102123                 660.0
# 1471             Out of Africa             52339                 200.0
# 1563            One True Thing              9283                 112.0
# 1132             Julie & Julia             79264                 277.0
# 2793  A Prairie Home Companion             19655                 280.0
# 1322     The Devil Wears Prada            286178                 631.0
# 392           It's Complicated             69860                 214.0
# 2500             The Iron Lady             82327                 350.0
# 1514              Hope Springs             34258                 178.0
# 1038            The River Wild             32544                  69.0
# 1390           Lions for Lambs             41170                 298.0
#
#      language      budget  title_year  imdb_score  movie_facebook_likes  \
# 1784  English  25000000.0      2002.0         7.6                     0
# 1471  English  31000000.0      1985.0         7.2                     0
# 1563  English  30000000.0      1998.0         7.0                   592
# 1132  English  40000000.0      2009.0         7.0                 13000
# 2793  English  10000000.0      2006.0         6.8                   683
# 1322  English  35000000.0      2006.0         6.8                     0
# 392   English  85000000.0      2009.0         6.6                     0
# 2500  English  13000000.0      2011.0         6.4                 18000
# 1514  English  30000000.0      2012.0         6.3                     0
# 1038  English  45000000.0      1994.0         6.3                     0
# 1390  English  35000000.0      2007.0         6.2                     0
#
#      Language      profit
# 1784  English  16597830.0
# 1471  English  56100000.0
# 1563  English  -6790560.0
# 1132  English  54125426.0
# 2793  English  10338609.0
# 1322  English  89732962.0
# 392   English  27703470.0
# 2500  English  16959436.0
# 1514  English  33536011.0
# 1038  English   1815748.0
# 1390  English -20001930.0

# %%
Leo_Caprio = movies[movies['actor_1_name']=='Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name num_critic_for_reviews        gross  \
# 94        Christopher Nolan                  642.0  292568851.0
# 347         Martin Scorsese                  352.0  132373442.0
# 283       Quentin Tarantino                  765.0  162804648.0
# 294         Martin Scorsese                  606.0  116866727.0
# 431         Martin Scorsese                  490.0  127968405.0
# 173   Alejandro G. Iñárritu                  556.0  183635922.0
# 859        Steven Spielberg                  194.0  164435221.0
# 293            Edward Zwick                  166.0   57366262.0
# 25            James Cameron                  315.0  658672302.0
# 246         Martin Scorsese                  267.0  102608827.0
# 312         Martin Scorsese                  233.0   77679638.0
# 1046             Sam Mendes                  323.0   22877808.0
# 3025           Baz Luhrmann                  490.0  144812796.0
# 49             Baz Luhrmann                  490.0  144812796.0
# 608            Ridley Scott                  238.0   39380442.0
# 2484           Baz Luhrmann                  106.0   46338728.0
# 1909             Jerry Zaks                   45.0   12782508.0
# 934             Danny Boyle                  118.0   39778599.0
# 1364         Clint Eastwood                  392.0   37304950.0
# 1336        Randall Wallace                   83.0   56876365.0
# 1457              Sam Raimi                   63.0   18636537.0
#
#                                 genres       actor_1_name  \
# 94    Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio
# 347               Crime|Drama|Thriller  Leonardo DiCaprio
# 283                      Drama|Western  Leonardo DiCaprio
# 294       Biography|Comedy|Crime|Drama  Leonardo DiCaprio
# 431                   Mystery|Thriller  Leonardo DiCaprio
# 173   Adventure|Drama|Thriller|Western  Leonardo DiCaprio
# 859              Biography|Crime|Drama  Leonardo DiCaprio
# 293           Adventure|Drama|Thriller  Leonardo DiCaprio
# 25                       Drama|Romance  Leonardo DiCaprio
# 246                    Biography|Drama  Leonardo DiCaprio
# 312                        Crime|Drama  Leonardo DiCaprio
# 1046                     Drama|Romance  Leonardo DiCaprio
# 3025                     Drama|Romance  Leonardo DiCaprio
# 49                       Drama|Romance  Leonardo DiCaprio
# 608              Action|Drama|Thriller  Leonardo DiCaprio
# 2484                     Drama|Romance  Leonardo DiCaprio
# 1909                             Drama  Leonardo DiCaprio
# 934           Adventure|Drama|Thriller  Leonardo DiCaprio
# 1364             Biography|Crime|Drama  Leonardo DiCaprio
# 1336                  Action|Adventure  Leonardo DiCaprio
# 1457           Action|Thriller|Western  Leonardo DiCaprio
#
#                     movie_title  num_voted_users  num_user_for_reviews  \
# 94                   Inception           1468200                2803.0
# 347               The Departed            873649                2054.0
# 283           Django Unchained            955174                1193.0
# 294    The Wolf of Wall Street            780588                1138.0
# 431             Shutter Island            786092                 964.0
# 173               The Revenant            406020                1188.0
# 859        Catch Me If You Can            525801                 667.0
# 293              Blood Diamond            400292                 657.0
# 25                     Titanic            793059                2528.0
# 246                The Aviator            264318                 799.0
# 312          Gangs of New York            314033                1166.0
# 1046        Revolutionary Road            152591                 414.0
# 3025          The Great Gatsby            362933                 753.0
# 49            The Great Gatsby            362912                 753.0
# 608               Body of Lies            174248                 263.0
# 2484            Romeo + Juliet            167750                 506.0
# 1909             Marvin's Room             20163                  71.0
# 934                  The Beach            176169                 548.0
# 1364                  J. Edgar            102728                 279.0
# 1336  The Man in the Iron Mask            125219                 244.0
# 1457    The Quick and the Dead             69197                 216.0
#
#      language       budget  title_year  imdb_score  movie_facebook_likes  \
# 94    English  160000000.0      2010.0         8.8                175000
# 347   English   90000000.0      2006.0         8.5                 29000
# 283   English  100000000.0      2012.0         8.5                199000
# 294   English  100000000.0      2013.0         8.2                138000
# 431   English   80000000.0      2010.0         8.1                 53000
# 173   English  135000000.0      2015.0         8.1                190000
# 859   English   52000000.0      2002.0         8.0                 15000
# 293   English  100000000.0      2006.0         8.0                 14000
# 25    English  200000000.0      1997.0         7.7                 26000
# 246   English  110000000.0      2004.0         7.5                     0
# 312   English  100000000.0      2002.0         7.5                     0
# 1046  English   35000000.0      2008.0         7.3                     0
# 3025  English  105000000.0      2013.0         7.3                115000
# 49    English  105000000.0      2013.0         7.3                115000
# 608   English   70000000.0      2008.0         7.1                     0
# 2484  English   14500000.0      1996.0         6.8                 10000
# 1909  English   23000000.0      1996.0         6.7                  1000
# 934   English   50000000.0      2000.0         6.6                     0
# 1364  English   35000000.0      2011.0         6.6                 16000
# 1336  English   35000000.0      1998.0         6.4                     0
# 1457  English   32000000.0      1995.0         6.4                     0
#
#      Language       profit
# 94    English  132568851.0
# 347   English   42373442.0
# 283   English   62804648.0
# 294   English   16866727.0
# 431   English   47968405.0
# 173   English   48635922.0
# 859   English  112435221.0
# 293   English  -42633738.0
# 25    English  458672302.0
# 246   English   -7391173.0
# 312   English  -22320362.0
# 1046  English  -12122192.0
# 3025  English   39812796.0
# 49    English   39812796.0
# 608   English  -30619558.0
# 2484  English   31838728.0
# 1909  English  -10217492.0
# 934   English  -10221401.0
# 1364  English    2304950.0
# 1336  English   21876365.0
# 1457  English  -13363463.0

# %%
Brad_Pitt = movies[movies['actor_1_name']=='Brad Pitt']
Brad_Pitt
# Out:
#               director_name num_critic_for_reviews        gross  \
# 646           David Fincher                  315.0   37023395.0
# 2602             Tony Scott                  122.0   12281500.0
# 97            David Fincher                  362.0  127490802.0
# 383       Steven Soderbergh                  186.0  183405771.0
# 887             Neil Jordan                  120.0  105264608.0
# 448              David Ayer                  406.0   85707116.0
# 1608         Andrew Dominik                  273.0    3904982.0
# 2030  Alejandro G. Iñárritu                  285.0   34300771.0
# 142       Wolfgang Petersen                  220.0  133228348.0
# 579     Jean-Jacques Annaud                   76.0   37901509.0
# 367              Tony Scott                  142.0      26871.0
# 749         Patrick Gilmore                   98.0   26288320.0
# 1397        Terrence Malick                  584.0   13303319.0
# 244              Doug Liman                  233.0  186336103.0
# 243       Steven Soderbergh                  198.0  125531634.0
# 2428         Andrew Dominik                  414.0   14938570.0
# 2146    Angelina Jolie Pitt                  131.0     531009.0
#
#                                                  genres actor_1_name  \
# 646                                               Drama    Brad Pitt
# 2602                Action|Crime|Drama|Romance|Thriller    Brad Pitt
# 97                                Drama|Fantasy|Romance    Brad Pitt
# 383                                      Crime|Thriller    Brad Pitt
# 887                                Drama|Fantasy|Horror    Brad Pitt
# 448                                    Action|Drama|War    Brad Pitt
# 1608              Biography|Crime|Drama|History|Western    Brad Pitt
# 2030                                              Drama    Brad Pitt
# 142                                           Adventure    Brad Pitt
# 579               Adventure|Biography|Drama|History|War    Brad Pitt
# 367                               Action|Crime|Thriller    Brad Pitt
# 749   Adventure|Animation|Comedy|Drama|Family|Fantas...    Brad Pitt
# 1397                                      Drama|Fantasy    Brad Pitt
# 244                Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 243                                      Crime|Thriller    Brad Pitt
# 2428                                     Crime|Thriller    Brad Pitt
# 2146                                      Drama|Romance    Brad Pitt
#
#                                             movie_title  num_voted_users  \
# 646                                         Fight Club           1347461
# 2602                                      True Romance            163492
# 97                 The Curious Case of Benjamin Button            459346
# 383                                     Ocean's Eleven            402645
# 887   Interview with the Vampire: The Vampire Chroni...           239752
# 448                                               Fury            303185
# 1608  The Assassination of Jesse James by the Coward...           136104
# 2030                                             Babel            243799
# 142                                               Troy            381672
# 579                               Seven Years in Tibet             96385
# 367                                           Spy Game            121259
# 749                   Sinbad: Legend of the Seven Seas             36144
# 1397                                  The Tree of Life            136367
# 244                                   Mr. & Mrs. Smith            348861
# 243                                     Ocean's Twelve            284852
# 2428                               Killing Them Softly            111625
# 2146                                        By the Sea              7976
#
#       num_user_for_reviews language       budget  title_year  imdb_score  \
# 646                 2968.0  English   63000000.0      1999.0         8.8
# 2602                 460.0  English   13000000.0      1993.0         8.0
# 97                   822.0  English  150000000.0      2008.0         7.8
# 383                  845.0  English   85000000.0      2001.0         7.8
# 887                  406.0  English   60000000.0      1994.0         7.6
# 448                  701.0  English   68000000.0      2014.0         7.6
# 1608                 415.0  English   30000000.0      2007.0         7.5
# 2030                 908.0  English   25000000.0      2006.0         7.5
# 142                 1694.0  English  175000000.0      2004.0         7.2
# 579                  119.0  English   70000000.0      1997.0         7.0
# 367                  361.0  English   92000000.0      2001.0         7.0
# 749                   91.0  English   60000000.0      2003.0         6.7
# 1397                 975.0  English   32000000.0      2011.0         6.7
# 244                  798.0  English  120000000.0      2005.0         6.5
# 243                  627.0  English  110000000.0      2004.0         6.4
# 2428                 369.0  English   15000000.0      2012.0         6.2
# 2146                  61.0  English   10000000.0      2015.0         5.3
#
#       movie_facebook_likes Language      profit
# 646                  48000  English -25976605.0
# 2602                 15000  English   -718500.0
# 97                   23000  English -22509198.0
# 383                      0  English  98405771.0
# 887                  11000  English  45264608.0
# 448                  82000  English  17707116.0
# 1608                     0  English -26095018.0
# 2030                     0  English   9300771.0
# 142                      0  English -41771652.0
# 579                      0  English -32098491.0
# 367                      0  English -91973129.0
# 749                    880  English -33711680.0
# 1397                 39000  English -18696681.0
# 244                      0  English  66336103.0
# 243                      0  English  15531634.0
# 2428                 20000  English    -61430.0
# 2146                     0  English  -9468991.0

# %%
#Write your code for combining the three dataframes here

Combined=pd.concat([Meryl_Streep,Leo_Caprio, Brad_Pitt],axis=0,ignore_index=True) 
Combined.groupby(by='actor_1_name').num_critic_for_reviews.mean()
Combined.groupby(by='actor_1_name').num_user_for_review.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13772\2474407900.py in <module>
#       3 Combined=pd.concat([Meryl_Streep,Leo_Caprio, Brad_Pitt],axis=0,ignore_index=True)
#       4 Combined.groupby(by='actor_1_name').num_critic_for_reviews.mean()
# ----> 5 Combined.groupby(by='actor_1_name').num_user_for_review.mean()
#
# c:\Users\ziyae\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'num_user_for_review'

# %%
Combined.set_index('actor_1_name')
# Out:
# c:\Users\ziyae\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#              director_name num_critic_for_reviews  gross genres movie_title  \
# actor_1_name
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
# NaN                    NaN                    NaN    NaN    NaN         NaN
#
#               num_voted_users  num_user_for_reviews language  budget  \
# actor_1_name
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
# NaN                       NaN                   NaN      NaN     NaN
#
#               title_year  imdb_score  movie_facebook_likes Language  profit
# actor_1_name
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
# NaN                  NaN         NaN                   NaN      NaN     NaN
